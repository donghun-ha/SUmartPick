# %% [markdown]
# # Nearest Neighbor product based Collaborative Filtering

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors

# %%
combined=pd.read_csv("Combined.csv")

# %%
combined.head()
# Out:
#    Unnamed: 0                          order_id  \
# 0           0  00010242fe8c5a6d1ba2dd792cb16214
# 1           1  00018f77f2f0320c557190d7a144bdd3
# 2           2  000229ec398224ef6ca0657da4fc703e
# 3           3  00024acbcdf0a6daa1e931b038114c75
# 4           4  00042b26cf59d7ce69dfabb4e55b4fd9
#
#                  customer_unique_id order_purchase_timestamp  \
# 0  3ce436f183e68e07877b285a838db11a      2017-09-13 08:59:02
# 1  f6dd3ec061db4e3987629fe6b26e5cce      2017-04-26 10:53:06
# 2  6489ae5e4333f3693df5ad4372dab6d3      2018-01-14 14:33:31
# 3  d4eb9395c8c0431ee92fce09860c5a06      2018-08-08 10:00:35
# 4  58dbd0b2d70206bf40e62cd34e84d795      2017-02-04 13:57:51
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2017-09-13 09:45:35          2017-09-19 18:34:16
# 1  2017-04-26 11:05:13          2017-05-04 14:35:00
# 2  2018-01-14 14:48:30          2018-01-16 12:36:48
# 3  2018-08-08 10:10:18          2018-08-10 13:28:00
# 4  2017-02-04 14:10:13          2017-02-16 09:46:09
#
#   order_delivered_customer_date order_estimated_delivery_date  order_item_id  \
# 0           2017-09-20 23:43:48                    2017-09-29            1.0
# 1           2017-05-12 16:04:24                    2017-05-15            1.0
# 2           2018-01-22 13:19:16                    2018-02-05            1.0
# 3           2018-08-14 13:32:39                    2018-08-20            1.0
# 4           2017-03-01 16:42:31                    2017-03-17            1.0
#
#                          product_id  ... seller_lat  seller_lng  \
# 0  4244733e06e7ecb4970a6e2683c13e61  ... -22.498183  -44.123614
# 1  e5f2d52b802189ee658865ca93d83a8f  ... -23.566258  -46.518417
# 2  c777355d18b72b67abbeef9df44fd0fd  ... -22.264094  -46.158564
# 3  7634da152a4610f1595efa32f14722fc  ... -20.548228  -47.395897
# 4  ac6c3623068f30de03045865e4e10089  ... -22.931427  -53.133759
#
#            customer_city  customer_state  customer_lat  customer_lng  \
# 0  campos dos goytacazes              RJ    -21.758076    -41.312633
# 1        santa fe do sul              SP    -20.212393    -50.941471
# 2          para de minas              MG    -19.860439    -44.597972
# 3                atibaia              SP    -23.144923    -46.539830
# 4        varzea paulista              SP    -23.249008    -46.824961
#
#    order_delivered_customer_time        dist product_category_name_english  \
# 0                         104972  301.005664                            기타
# 1                         696564  589.274140                       유아/애완용품
# 2                         520948  312.495046                       가구/인테리어
# 3                         345879  301.951753                         뷰티/건강
# 4                        1148182  646.221788                       가구/인테리어
#
#    review_score
# 0           5.0
# 1           4.0
# 2           5.0
# 3           4.0
# 4           5.0
#
# [5 rows x 29 columns]

# %%
df1=pd.read_csv("combined.csv",usecols=['product_id','customer_unique_id','product_category_name_english','review_score'])

# %%
df1.head()
# Out:
#                  customer_unique_id                        product_id  \
# 0  3ce436f183e68e07877b285a838db11a  4244733e06e7ecb4970a6e2683c13e61
# 1  f6dd3ec061db4e3987629fe6b26e5cce  e5f2d52b802189ee658865ca93d83a8f
# 2  6489ae5e4333f3693df5ad4372dab6d3  c777355d18b72b67abbeef9df44fd0fd
# 3  d4eb9395c8c0431ee92fce09860c5a06  7634da152a4610f1595efa32f14722fc
# 4  58dbd0b2d70206bf40e62cd34e84d795  ac6c3623068f30de03045865e4e10089
#
#   product_category_name_english  review_score
# 0                            기타           5.0
# 1                       유아/애완용품           4.0
# 2                       가구/인테리어           5.0
# 3                         뷰티/건강           4.0
# 4                       가구/인테리어           5.0

# %% [markdown]
# Combine total product review and count the total reviews

# %%
combine_product_review = df1.dropna(axis = 0, subset = ['product_category_name_english'])
product_reviewCount = (combine_product_review.
     groupby(by = ['product_category_name_english'])['review_score'].
     count().
     reset_index().
     rename(columns = {'review_score': 'totalReviewCount'})
     [['product_category_name_english','totalReviewCount']]
    )
product_reviewCount.head()
# Out:
#   product_category_name_english  totalReviewCount
# 0                       가구/인테리어             14885
# 1                            기타              8628
# 2                         도서/교육               852
# 3                    미디어/엔터테인먼트              1260
# 4                         뷰티/건강             12795

# %% [markdown]
# # After merging Total review count column into dataset

# %%
review_with_totalReviewCount  = combine_product_review.merge(product_reviewCount, left_on = 'product_category_name_english', right_on = 'product_category_name_english', how = 'left')
review_with_totalReviewCount.head()
# Out:
#                  customer_unique_id                        product_id  \
# 0  3ce436f183e68e07877b285a838db11a  4244733e06e7ecb4970a6e2683c13e61
# 1  f6dd3ec061db4e3987629fe6b26e5cce  e5f2d52b802189ee658865ca93d83a8f
# 2  6489ae5e4333f3693df5ad4372dab6d3  c777355d18b72b67abbeef9df44fd0fd
# 3  d4eb9395c8c0431ee92fce09860c5a06  7634da152a4610f1595efa32f14722fc
# 4  58dbd0b2d70206bf40e62cd34e84d795  ac6c3623068f30de03045865e4e10089
#
#   product_category_name_english  review_score  totalReviewCount
# 0                            기타           5.0              8628
# 1                       유아/애완용품           4.0              8825
# 2                       가구/인테리어           5.0             14885
# 3                         뷰티/건강           4.0             12795
# 4                       가구/인테리어           5.0             14885

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
print(product_reviewCount['totalReviewCount'].describe())
# Out:
# count      10.000
# mean     8350.600
# std      5796.878
# min       852.000
# 25%      3056.250
# 50%      8726.500
# 75%     11950.000
# max     17281.000
# Name: totalReviewCount, dtype: float64

# %% [markdown]
# filtering out products that have less than 100 reviews

# %%
popularity_threshold =100
review_popular_product= review_with_totalReviewCount.query('totalReviewCount >= @popularity_threshold')
review_popular_product.head()
# Out:
#                  customer_unique_id                        product_id  \
# 0  3ce436f183e68e07877b285a838db11a  4244733e06e7ecb4970a6e2683c13e61
# 1  f6dd3ec061db4e3987629fe6b26e5cce  e5f2d52b802189ee658865ca93d83a8f
# 2  6489ae5e4333f3693df5ad4372dab6d3  c777355d18b72b67abbeef9df44fd0fd
# 3  d4eb9395c8c0431ee92fce09860c5a06  7634da152a4610f1595efa32f14722fc
# 4  58dbd0b2d70206bf40e62cd34e84d795  ac6c3623068f30de03045865e4e10089
#
#   product_category_name_english  review_score  totalReviewCount
# 0                            기타         5.000              8628
# 1                       유아/애완용품         4.000              8825
# 2                       가구/인테리어         5.000             14885
# 3                         뷰티/건강         4.000             12795
# 4                       가구/인테리어         5.000             14885

# %%
review_popular_product.shape
# Out:
# (84096, 5)

# %% [markdown]
# # create a Pivot matrix

# %%
product_features_df=review_popular_product.pivot_table(index='product_category_name_english',columns='customer_unique_id',values='review_score').fillna(0)
product_features_df.head()
# Out:
# customer_unique_id             00012a2ce6f8dcda20d059ce98491703  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     0.000
#
# customer_unique_id             000161a058600d5901f007fab4c27140  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     4.000
#
# customer_unique_id             0001fd6190edaaf884bcaf3d49edf079  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     0.000
#
# customer_unique_id             0002414f95344307404f0ace7a26f1d5  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        5.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     0.000
#
# customer_unique_id             0004164d20a9e969af783496f3408652  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     0.000
#
# customer_unique_id             000419c5494106c306a97b5635748086  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     0.000
#
# customer_unique_id             00046a560d407e99b969756e0b10f282  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     0.000
#
# customer_unique_id             00050bf6e01e69d5c0fd612f1bcfb69c  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     0.000
#
# customer_unique_id             000598caf2ef4117407665ac33275130  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     0.000
#
# customer_unique_id             00062b33cb9f6fe976afdcff967ea74d  ...  \
# product_category_name_english                                    ...
# 가구/인테리어                                                   0.000  ...
# 기타                                                        0.000  ...
# 도서/교육                                                     0.000  ...
# 미디어/엔터테인먼트                                                0.000  ...
# 뷰티/건강                                                     3.000  ...
#
# customer_unique_id             fff5169e583fd07fac9fec88962f189d  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     1.000
#
# customer_unique_id             fff55ba8dffa552b6fdfd86c2e806459  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     3.000
#
# customer_unique_id             fff5dd22d522cf28a902185817642a2e  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     0.000
#
# customer_unique_id             fff675a0d5924b9162b4a1bf410466cd  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     0.000
#
# customer_unique_id             fff7466a253c0e59499ea943462c10f9  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     5.000
#
# customer_unique_id             fff93c1da78dafaaa304ff032abc6205  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     5.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     0.000
#
# customer_unique_id             fffa0238b217e18a8adeeda0669923a3  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     5.000
#
# customer_unique_id             fffcb937e9dd47a13f05ecb8290f4d3e  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     5.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     0.000
#
# customer_unique_id             fffeda5b6d849fbd39689bb92087f431  \
# product_category_name_english
# 가구/인테리어                                                   0.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     0.000
#
# customer_unique_id             ffffa3172527f765de70084a7e53aae8
# product_category_name_english
# 가구/인테리어                                                   5.000
# 기타                                                        0.000
# 도서/교육                                                     0.000
# 미디어/엔터테인먼트                                                0.000
# 뷰티/건강                                                     0.000
#
# [5 rows x 73315 columns]

# %%
from scipy.sparse import csr_matrix

product_features_df_matrix = csr_matrix(product_features_df.values)

# %%
from sklearn.neighbors import NearestNeighbors

model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model_knn.fit(product_features_df_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
product_features_df.shape
# Out:
# (10, 73315)

# %% [markdown]
# # choose a random product

# %%
query_index = np.random.choice(product_features_df.shape[0])
print(query_index)
distances, indices = model_knn.kneighbors(product_features_df.iloc[query_index,:].values.reshape(1, -1), n_neighbors = 6)
# Out:
# 8

# %% [markdown]
# # Based on that product what we have choosen 5 nearest distance product get recommended

# %%
for i in range(0, len(distances.flatten())):
    if i == 0:
        print('Recommendations for {0}:\n'.format(product_features_df.index[query_index]))
    else:
        print('{0}: {1}, with distance of {2}:'.format(i, product_features_df.index[indices.flatten()[i]], distances.flatten()[i]))
# Out:
# Recommendations for 전자제품/기술:
#
# 1: 기타, with distance of 0.9989063982445366:
# 2: 가구/인테리어, with distance of 0.9990783569046878:
# 3: 패션/액세서리, with distance of 0.9990886430870719:
# 4: 식품/음료, with distance of 0.9995354699531809:
# 5: 뷰티/건강, with distance of 0.9995433563452749:
